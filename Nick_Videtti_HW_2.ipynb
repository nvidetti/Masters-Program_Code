# %% [markdown]
# Nick Videtti
# <br>
# IST 664 - Natural Language Processing - Winter 2023
# <br>
# Homework 2
# <br>
# March 12th, 2023
# <br>
# <br>
# This assignment will take two documents and perform a sentence tokenization on them, then will calculate some descriptive statistics corresponding to those sentences.
# <br>
# The two documents are Monty Python and the Holy Grail from the nltk.book package and a text file containing prose that was
# <br>
# copied and pasted from a Wikipedia page on 2/4/2023 about History of the New York Knicks (https://en.wikipedia.org/wiki/History_of_the_New_York_Knicks).
# <br>
# <br>
# More will follow once the documents have been properly tokenized, but let's focus on that first!
# <br>
# There are three fundamental steps to this initial tokenizaion:
# <br>
# &emsp;1. Tokenizing the raw text. This will help split the documents into a list of its sentences.
# <br>
# &emsp;2. Tag the sentences with Part of Speech (POS) tags.
# <br>
# &emsp;3. Filter each document to only include sentences that contain adjectives and/or adverbs. These will correspond with POS tags of "JJ", "JJR", "JJS" for adjectives and "RB", "RBR", "RBS", "WRB" for adverbs.

# %%
#Import the Natural Language Toolkit and the nltk.book package
import nltk
from nltk import book

#Monty Python and the Holy Grail sentence tokens
#Turn word tokens into one string of raw text
Monty_Python_text = ' '.join([word for word in nltk.book.text6.tokens])
#Tokenize sentences
Monty_Python_sentences = nltk.sent_tokenize(Monty_Python_text)

#Knicks History with tokenizing
#source: Wikipedia - https://en.wikipedia.org/wiki/History_of_the_New_York_Knicks
with open('C:/Users/nvidetti/Downloads/History of Knicks Wiki.txt','r', encoding = 'utf-8') as Knicks_History_Text_File: Knicks_History = Knicks_History_Text_File.read()
Knicks_History_sentences = nltk.sent_tokenize(Knicks_History)

# %%
#Tokenze the words in each sentence for Monty Python sentences
Monty_Python_sentences = [nltk.word_tokenize(sent) for sent in Monty_Python_sentences]

#Tokenze the words in each sentence for Knicks History sentences
Knicks_History_sentences = [nltk.word_tokenize(sent) for sent in Knicks_History_sentences]

# %%
#Tag all words in all sentences with POS tags
Monty_Python_sentences_tagged = [nltk.pos_tag(sent) for sent in Monty_Python_sentences]
Knicks_History_sentences_tagged = [nltk.pos_tag(sent) for sent in Knicks_History_sentences]

#Find all sentence indices that contains words with adjective and/or adverb POS tags
Monty_filter_indices = set()
for sent_index in range(len(Monty_Python_sentences_tagged)):
    for (word,tag) in Monty_Python_sentences_tagged[sent_index]:
        if tag in ('JJ','JJR','JJS','RB','RBR','RBS','WRB'): Monty_filter_indices.add(sent_index)
Knicks_filter_indices = set()
for sent_index in range(len(Knicks_History_sentences_tagged)):
    for (word,tag) in Knicks_History_sentences_tagged[sent_index]:
        if tag in ('JJ','JJR','JJS','RB','RBR','RBS','WRB'): Knicks_filter_indices.add(sent_index)


#Filter to only sentences that have adjective and/or adverb POS tags
Monty_filtered = [sent for sent in Monty_Python_sentences_tagged if Monty_Python_sentences_tagged.index(sent) in Monty_filter_indices]
Knicks_filtered = [sent for sent in Knicks_History_sentences_tagged if Knicks_History_sentences_tagged.index(sent) in Knicks_filter_indices]

#Number of sentences in each step
#Monty Python
print('SUMMARY OF INITIAL TOKENIZATION\n\nMonty Python and The Holy Grail\nFull Text:', len(Monty_Python_sentences), 'sentences')
print('Filtered Text:', len(Monty_filtered), 'sentences', len(Monty_Python_sentences) - len(Monty_filtered), 'removed')

#Knicks_History
print('\n\nKnicks History\nFull Text:', len(Knicks_History_sentences), 'sentences')
print('Filtered Text:', len(Knicks_filtered), 'sentences', len(Knicks_History_sentences) - len(Knicks_filtered), 'removed')
# Out:
# SUMMARY OF INITIAL TOKENIZATION
#
# Monty Python and The Holy Grail
# Full Text: 1874 sentences
# Filtered Text: 829 sentences 1045 removed
#
#
# Knicks History
# Full Text: 367 sentences
# Filtered Text: 348 sentences 19 removed

# %% [markdown]
# Great!!
# <br>
# We have now pulled the raw texts from their sources, converted each to a list of its sentences, and converted each of those sentences to a list of its words.
# <br>
# We also have tagged each word in with Part of Speech (POS) tags, and filtered each of the sentences to only those which contain the adjective (JJ, JJR, JJS) and/or adverb (RB, RBR, RBS, WRB) POS tags.
# <br>
# <br>
# Let's take a quick look at the first few sentences of each of the texts.

# %%
print('First 5 Monty Python Sentences:')
for sent in Monty_filtered[:5]: print(sent,'\n')

print('\n\nFirst 5 Knicks History Sentneces:')
for sent in Knicks_filtered[:5]: print(sent,'\n')
# Out:
# First 5 Monty Python Sentences:
# [('SCENE', 'NN'), ('1', 'CD'), (':', ':'), ('[', 'NN'), ('wind', 'IN'), (']', 'JJ'), ('[', 'NNP'), ('clop', 'NN'), ('clop', 'NN'), ('clop', 'NN'), (']', 'NNP'), ('KING', 'NNP'), ('ARTHUR', 'NNP'), (':', ':'), ('Whoa', 'NNP'), ('there', 'EX'), ('!', '.')]
#
# [('Who', 'WP'), ('goes', 'VBZ'), ('there', 'RB'), ('?', '.')]
#
# [('SOLDIER', 'NNP'), ('#', '#'), ('1', 'CD'), (':', ':'), ('Pull', 'VB'), ('the', 'DT'), ('other', 'JJ'), ('one', 'CD'), ('!', '.')]
#
# [('ARTHUR', 'NNP'), (':', ':'), ('I', 'PRP'), ('am', 'VBP'), (',', ','), ('...', ':'), ('and', 'CC'), ('this', 'DT'), ('is', 'VBZ'), ('my', 'PRP$'), ('trusty', 'JJ'), ('servant', 'JJ'), ('Patsy', 'NNP'), ('.', '.')]
#
# ...

# %% [markdown]
# Now it is time to do some descriptive statistics on these sentences!
# <br>
# <br>
# While countless metrics can be calculated, these five sets of metrics will be evaluated for each of the filtered sets of sentnences:
# <br>
# <br>&emsp;1. Total number of sentnences, words, characters, adjectves, and adverbs
# <br>&emsp;2. Min, Max, and Average sentence length measured both in words and characters
# <br>&emsp;3. Min, Max, and Average number of adjectives and adverbs per sentence
# <br>&emsp;4. Min, Max, and Average word length for adjectives and adverbs
# <br>&emsp;5. 20 Most Common Adjectives and Adverbs by Frequency

# %% [markdown]
# Metric Set 1:
# <br>
# Total number of sentnences, words, characters, adjectve phrases, and adverb phrases
# <br>
# <br>
# We can find these using the filtered sentences and performing calcualtions on them.

# %%
#Total number of sentences, words, characters, adjectives, and adverbs
import pandas
DF1 = pandas.DataFrame(index = ['Sentences', 'Words', 'Characters', 'Adjectives', 'Adverbs'], columns = ['Filtered Monty Python','Filtered Knicks History'])
#Total number of sentences
DF1.loc['Sentences']['Filtered Monty Python'] = len(Monty_filtered)
DF1.loc['Sentences']['Filtered Knicks History'] = len(Knicks_filtered)
#Total number of words
DF1.loc['Words']['Filtered Monty Python'] = sum([len(sent) for sentDF1 in Monty_filtered])
DF1.loc['Words']['Filtered Knicks History'] = sum([len(sent) for sentDF1 in Knicks_filtered])
#Total number of characters
DF1.loc['Characters']['Filtered Monty Python'] = sum([len(word) for (word,tag) in sent for sent in Monty_filtered])
DF1.loc['Characters']['Filtered Knicks History'] = sum([len(word) for (word,tag) in sent for sent in Knicks_filtered])
#Total number of adjectives
DF1.loc['Adjectives']['Filtered Monty Python'] = sum([len(word[0]) for (word,tag) in sent for sent in Monty_filtered if tag in ('JJ', 'JJR', 'JJS')])
DF1.loc['Adjectives']['Filtered Knicks History'] = sum([len(word[0]) for (word,tag) in sent for sent in Knicks_filtered if tag in ('JJ', 'JJR', 'JJS')])
#Total number of adverbs
DF1.loc['Adverbs']['Filtered Monty Python'] = sum([len(word[0]) for (word,tag) in sent for sent in Monty_filtered if tag in ('RB', 'RBR', 'RBS', 'WRB')])
DF1.loc['Adverbs']['Filtered Knicks History'] = sum([len(word[0]) for (word,tag) in sent for sent in Knicks_filtered if tag in ('RB', 'RBR', 'RBS', 'WRB')])
#Display results
DF1
# Out:
#            Filtered Monty Python Filtered Knicks History
# Sentences                    829                     348
# Words                      24041                   10092
# Characters                121863                   51156
# Adjectives                  2487                    1044
# Adverbs                     1658                     696

# %% [markdown]
# Metric Set 2:
# <br>
# Min, Max, and Average sentence length measured both in words and characters
# <br>
# <br>
# We will once again use the filtered sentences to calcaulate the lenghts in words, but will need to calculate the number of characters per sentence to find the sentence lengths in characters.

# %%
#Min, Max, Average sentences length in both words and characters
DF2 = pandas.DataFrame(index = ['Min Sentence Length (Words)', 'Max Sentence Length (Words)', 'Average Sentence Length (Words)',
                                'Min Sentence Length (Characters)', 'Max Sentence Length (Characters)', 'Average Sentence Length (Characters)']
                                , columns = ['Filtered Monty Python','Filtered Knicks History'])
#Sentences lengths (words)
DF2.loc['Min Sentence Length (Words)']['Filtered Monty Python'] = min([len(sent) for sent in Monty_filtered])
DF2.loc['Max Sentence Length (Words)']['Filtered Monty Python'] = max([len(sent) for sent in Monty_filtered])
DF2.loc['Average Sentence Length (Words)']['Filtered Monty Python'] = sum([len(sent) for sent in Monty_filtered]) / len(Monty_filtered)
DF2.loc['Min Sentence Length (Words)']['Filtered Knicks History'] = min([len(sent) for sent in Knicks_filtered])
DF2.loc['Max Sentence Length (Words)']['Filtered Knicks History'] = max([len(sent) for sent in Knicks_filtered])
DF2.loc['Average Sentence Length (Words)']['Filtered Knicks History'] = sum([len(sent) for sent in Knicks_filtered]) / len(Knicks_filtered)
#Sentence lengths (characters)
#Find characters per sentence
Monty_filtered_sent_chars = []
for sent in Monty_filtered: Monty_filtered_sent_chars.append(sum([len(word) for (word,tag) in sent]))
Knicks_filtered_sent_chars = []
for sent in Knicks_filtered: Knicks_filtered_sent_chars.append(sum([len(word) for (word,tag) in sent]))
#Calculate sentence lengths
DF2.loc['Min Sentence Length (Characters)']['Filtered Monty Python'] = min(Monty_filtered_sent_chars)
DF2.loc['Max Sentence Length (Characters)']['Filtered Monty Python'] = max(Monty_filtered_sent_chars)
DF2.loc['Average Sentence Length (Characters)']['Filtered Monty Python'] = sum(Monty_filtered_sent_chars) / len(Monty_filtered_sent_chars)
DF2.loc['Min Sentence Length (Characters)']['Filtered Knicks History'] = min(Knicks_filtered_sent_chars)
DF2.loc['Max Sentence Length (Characters)']['Filtered Knicks History'] = max(Knicks_filtered_sent_chars)
DF2.loc['Average Sentence Length (Characters)']['Filtered Knicks History'] = sum(Knicks_filtered_sent_chars) / len(Knicks_filtered_sent_chars)
#Display results
DF2
# Out:
#                                      Filtered Monty Python  \
# Min Sentence Length (Words)                              2
# Max Sentence Length (Words)                            118
# Average Sentence Length (Words)                  12.861279
# Min Sentence Length (Characters)                         5
# Max Sentence Length (Characters)                       427
# Average Sentence Length (Characters)             41.104946
#
#                                      Filtered Knicks History
# Min Sentence Length (Words)                                3
# Max Sentence Length (Words)                               84
# Average Sentence Length (Words)                    30.241379
# Min Sentence Length (Characters)                           5
# Max Sentence Length (Characters)                         413
# Average Sentence Length (Characters)              126.112069

# %% [markdown]
# Metric Set 3:
# <br>
# Min, Max, and Average number of adjectives and adverbs per sentence
# <br>
# <br>
# Much like the characters per sentence for the sentence lengths, we will need to find the adjectives and adverbs per sentence for this analysis.

# %%
#Min, Max, Average adjectives and adverbs per sentence
DF3 = pandas.DataFrame(index = ['Min Adjectives in Sentence', 'Max Adjectives in Sentence', 'Average Adjectives in Sentence',
                                'Min Adverbs in Sentence', 'Max Adverbs in Sentence', 'Average Adverbs in Sentence']
                                , columns = ['Filtered Monty Python','Filtered Knicks History'])
#Find adjectives and adverbs per sentence
Monty_filtered_sent_adjs = []
for sent in Monty_filtered: Monty_filtered_sent_adjs.append(sum([len(word[0]) for (word,tag) in sent if tag in ('JJ', 'JJR', 'JJS')]))
Knicks_filtered_sent_adjs = []
for sent in Knicks_filtered: Knicks_filtered_sent_adjs.append(sum([len(word[0]) for (word,tag) in sent if tag in ('JJ', 'JJR', 'JJS')]))
Monty_filtered_sent_advs = []
for sent in Monty_filtered: Monty_filtered_sent_advs.append(sum([len(word[0]) for (word,tag) in sent if tag in ('RB', 'RBR', 'RBS', 'WRB')]))
Knicks_filtered_sent_advs = []
for sent in Knicks_filtered: Knicks_filtered_sent_advs.append(sum([len(word[0]) for (word,tag) in sent if tag in ('RB', 'RBR', 'RBS', 'WRB')]))

#Calculate metrics
DF3.loc['Min Adjectives in Sentence']['Filtered Monty Python'] = min(Monty_filtered_sent_adjs)
DF3.loc['Max Adjectives in Sentence']['Filtered Monty Python'] = max(Monty_filtered_sent_adjs)
DF3.loc['Average Adjectives in Sentence']['Filtered Monty Python'] = sum(Monty_filtered_sent_adjs) / len(Monty_filtered_sent_adjs)
DF3.loc['Min Adverbs in Sentence']['Filtered Monty Python'] = min(Monty_filtered_sent_advs)
DF3.loc['Max Adverbs in Sentence']['Filtered Monty Python'] = max(Monty_filtered_sent_advs)
DF3.loc['Average Adverbs in Sentence']['Filtered Monty Python'] = sum(Monty_filtered_sent_advs) / len(Monty_filtered_sent_advs)
DF3.loc['Min Adjectives in Sentence']['Filtered Knicks History'] = min(Knicks_filtered_sent_adjs)
DF3.loc['Max Adjectives in Sentence']['Filtered Knicks History'] = max(Knicks_filtered_sent_adjs)
DF3.loc['Average Adjectives in Sentence']['Filtered Knicks History'] = sum(Knicks_filtered_sent_adjs) / len(Knicks_filtered_sent_adjs)
DF3.loc['Min Adverbs in Sentence']['Filtered Knicks History'] = min(Knicks_filtered_sent_advs)
DF3.loc['Max Adverbs in Sentence']['Filtered Knicks History'] = max(Knicks_filtered_sent_advs)
DF3.loc['Average Adverbs in Sentence']['Filtered Knicks History'] = sum(Knicks_filtered_sent_advs) / len(Knicks_filtered_sent_advs)

#Display results
DF3
# Out:
#                                Filtered Monty Python Filtered Knicks History
# Min Adjectives in Sentence                         0                       0
# Max Adjectives in Sentence                        24                       8
# Average Adjectives in Sentence              1.022919                1.652299
# Min Adverbs in Sentence                            0                       0
# Max Adverbs in Sentence                           10                       7
# Average Adverbs in Sentence                 0.798552                1.344828

# %% [markdown]
# Metric Set 4:
# <br>
# Min, Max, and Average word length for adjectives and adverbs
# <br>
# <br>
# This step will require we first find all adjectives and all adverbs separately.

# %%
#Min, Max, Average word lengths adjectives and adverbs
DF4 = pandas.DataFrame(index = ['Min Adjective Length', 'Max Adjective Length', 'Average Adjective Length',
                                'Min Adverb Length', 'Max Adverb Length', 'Average Adverb Length']
                                , columns = ['Filtered Monty Python','Filtered Knicks History'])
#Find adverbs per sentence
#Monty adjectives
Monty_adjs = []
for sent in Monty_filtered: 
    for (word,tag) in sent:
        if tag in ('JJ', 'JJR', 'JJS'): Monty_adjs.append(word)
#Knicks adjectives
Knicks_adjs = []
for sent in Knicks_filtered: 
    for (word,tag) in sent:
        if tag in ('JJ', 'JJR', 'JJS'): Knicks_adjs.append(word)
#Monty adverbs
Monty_advs = []
for sent in Monty_filtered: 
    for (word,tag) in sent:
        if tag in ('RB', 'RBR', 'RBS', 'WRB'): Monty_advs.append(word)
#Knicks adverbs
Knicks_advs = []
for sent in Knicks_filtered: 
    for (word,tag) in sent:
        if tag in ('RB', 'RBR', 'RBS', 'WRB'): Knicks_advs.append(word)

#Calculate metrics
DF4.loc['Min Adjective Length']['Filtered Monty Python'] = min([len(word) for word in Monty_adjs])
DF4.loc['Max Adjective Length']['Filtered Monty Python'] = max([len(word) for word in Monty_adjs])
DF4.loc['Average Adjective Length']['Filtered Monty Python'] = sum([len(word) for word in Monty_adjs]) / len(Monty_adjs)
DF4.loc['Min Adverb Length']['Filtered Monty Python'] = min([len(word) for word in Monty_advs])
DF4.loc['Max Adverb Length']['Filtered Monty Python'] = max([len(word) for word in Monty_advs])
DF4.loc['Average Adverb Length']['Filtered Monty Python'] = sum([len(word) for word in Monty_advs]) / len(Monty_advs)
DF4.loc['Min Adjective Length']['Filtered Knicks History'] = min([len(word) for word in Knicks_adjs])
DF4.loc['Max Adjective Length']['Filtered Knicks History'] = max([len(word) for word in Knicks_adjs])
DF4.loc['Average Adjective Length']['Filtered Knicks History'] = sum([len(word) for word in Knicks_adjs]) / len(Knicks_adjs)
DF4.loc['Min Adverb Length']['Filtered Knicks History'] = min([len(word) for word in Knicks_advs])
DF4.loc['Max Adverb Length']['Filtered Knicks History'] = max([len(word) for word in Knicks_advs])
DF4.loc['Average Adverb Length']['Filtered Knicks History'] = sum([len(word) for word in Knicks_advs]) / len(Knicks_advs)

#Display results
DF4
# Out:
#                          Filtered Monty Python Filtered Knicks History
# Min Adjective Length                         1                       1
# Max Adjective Length                        13                      18
# Average Adjective Length              4.211085                6.086957
# Min Adverb Length                            1                       1
# Max Adverb Length                           13                      13
# Average Adverb Length                 4.302115                3.425214

# %% [markdown]
# Before moving onto the fifth and final set of metrics, let's combine the four tables we created into one in order to see all results at once!
# <br>
# (this will not be necessary for the fith set of metrics, since those are at the adjective / adverb level rather than the document level)
# <br>
# <br>
# We will also calculate aggregates for all metrics other than the averages, as averaging those averages would be misleading.

# %%
#Combined dataframe
DF1234 = pandas.concat([DF1,DF2,DF3,DF4])

#Create aggregated column
DF1234['Both'] = pandas.Series('float64')

#Calculate metrics
DF1234.loc['Sentences']['Both'] = sum(DF1234.loc['Sentences'][:2])
DF1234.loc['Words']['Both'] = sum(DF1234.loc['Words'][:2])
DF1234.loc['Characters']['Both'] = sum(DF1234.loc['Characters'][:2])
DF1234.loc['Adjectives']['Both'] = sum(DF1234.loc['Adjectives'][:2])
DF1234.loc['Adverbs']['Both'] = sum(DF1234.loc['Adverbs'][:2])
DF1234.loc['Min Sentence Length (Words)']['Both'] = min(DF1234.loc['Min Sentence Length (Words)'][:2])
DF1234.loc['Max Sentence Length (Words)']['Both'] = max(DF1234.loc['Max Sentence Length (Words)'][:2])
DF1234.loc['Min Sentence Length (Characters)']['Both'] = min(DF1234.loc['Min Sentence Length (Characters)'][:2])
DF1234.loc['Max Sentence Length (Characters)']['Both'] = max(DF1234.loc['Max Sentence Length (Characters)'][:2])
DF1234.loc['Min Adjectives in Sentence']['Both'] = min(DF1234.loc['Min Adjectives in Sentence'][:2])
DF1234.loc['Max Adjectives in Sentence']['Both'] = max(DF1234.loc['Max Adjectives in Sentence'][:2])
DF1234.loc['Min Adverbs in Sentence']['Both'] = min(DF1234.loc['Min Adverbs in Sentence'][:2])
DF1234.loc['Max Adverbs in Sentence']['Both'] = max(DF1234.loc['Max Adverbs in Sentence'][:2])
DF1234.loc['Min Adjective Length']['Both'] = min(DF1234.loc['Min Adjective Length'][:2])
DF1234.loc['Max Adjective Length']['Both'] = max(DF1234.loc['Max Adjective Length'][:2])
DF1234.loc['Min Adverb Length']['Both'] = min(DF1234.loc['Min Adverb Length'][:2])
DF1234.loc['Max Adverb Length']['Both'] = max(DF1234.loc['Max Adverb Length'][:2])

#Display results
DF1234
# Out:
#                                      Filtered Monty Python  \
# Sentences                                              829
# Words                                                24041
# Characters                                          121863
# Adjectives                                            2487
# Adverbs                                               1658
# Min Sentence Length (Words)                              2
# Max Sentence Length (Words)                            118
# Average Sentence Length (Words)                  12.861279
# Min Sentence Length (Characters)                         5
# Max Sentence Length (Characters)                       427
# Average Sentence Length (Characters)             41.104946
# Min Adjectives in Sentence                               0
# Max Adjectives in Sentence                              24
# Average Adjectives in Sentence                    1.022919
# Min Adverbs in Sentence                                  0
# ...

# %% [markdown]
# Awesome!! Now, last but not least......
# <br>
# <br>
# <br>
# Metric Set 5:
# <br>
# 20 Most Common Adjectives and Adverbs by Frequency
# <br>
# <br>
# We can use the lists of adjectives and adverbs generated in the last step, but will also create a list for both document's adjectives / adverbs combined.

# %%
#20 Most Common Adjectives and Adverbs
#First, create combined adjective and adverb lists
adjs = Monty_adjs + Knicks_adjs
advs = Monty_advs + Knicks_advs

#Monty Python Adjectives
print('TOP 20 MONTY PYTHON ADJECTIVES')
for row in nltk.FreqDist(Monty_adjs).most_common()[:20]: print(row[0], row[1])
# Out:
# TOP 20 MONTY PYTHON ADJECTIVES
# [ 80
# ] 47
# s 47
# mumble 30
# dead 22
# FRENCH 22
# t 19
# re 12
# ll 12
# good 10
# more 10
# DEAD 8
# m 8
# sure 8
# MIDDLE 8
# old 7
# nice 7
# last 7
# squeak 7
# RIGHT 7

# %%
#Monty Python Adverbs
print('TOP 20 MONTY PYTHON ADVERBS')
for row in nltk.FreqDist(Monty_advs).most_common()[:20]: print(row[0], row[1])
# Out:
# TOP 20 MONTY PYTHON ADVERBS
# not 74
# Well 41
# away 35
# here 34
# just 25
# Right 24
# very 17
# so 16
# then 15
# So 14
# Not 12
# when 12
# now 12
# there 11
# again 10
# Just 10
# back 9
# Now 9
# How 8
# Then 8

# %%
#Knicks History Adjectives
print('TOP 20 KNICKS HISTORY ADJECTIVES')
for row in nltk.FreqDist(Knicks_adjs).most_common()[:20]: print(row[0], row[1])
# Out:
# TOP 20 KNICKS HISTORY ADJECTIVES
# ] 71
# first 70
# second 22
# former 16
# next 12
# straight 7
# worst 7
# many 6
# new 6
# final 6
# general 5
# successful 5
# more 5
# interim 5
# following 5
# consecutive 5
# regular 5
# such 5
# professional 4
# last 4

# %%
#Knicks History Adjverbs
print('TOP 20 KNICKS HISTORY ADVERBS')
for row in nltk.FreqDist(Knicks_advs).most_common()[:20]: print(row[0], row[1])
# Out:
# TOP 20 KNICKS HISTORY ADVERBS
# [ 221
# not 18
# also 18
# however 13
# However 13
# when 9
# where 9
# later 9
# forward 9
# again 7
# prior 6
# then 5
# more 5
# well 5
# still 5
# most 5
# once 5
# only 5
# much 4
# together 3

# %%
#All Adjectives
print('TOP 20 ADJECTIVES IN COMBINED DOCUMENTS')
for row in nltk.FreqDist(adjs).most_common()[:20]: print(row[0], row[1])
# Out:
# TOP 20 ADJECTIVES IN COMBINED DOCUMENTS
# ] 118
# [ 81
# first 72
# s 47
# mumble 30
# second 28
# dead 22
# FRENCH 22
# t 19
# former 16
# more 15
# next 14
# good 14
# re 12
# ll 12
# last 11
# many 10
# new 9
# DEAD 8
# m 8

# %%
#All Adverbs
print('TOP 20 ADVERBS IN COMBINED DOCUMENTS')
for row in nltk.FreqDist(advs).most_common()[:20]: print(row[0], row[1])
# Out:
# TOP 20 ADVERBS IN COMBINED DOCUMENTS
# [ 222
# not 92
# Well 41
# away 36
# here 34
# just 26
# Right 24
# when 21
# then 20
# also 20
# so 18
# very 17
# again 17
# where 15
# So 14
# Not 13
# however 13
# However 13
# back 12
# now 12

# %% [markdown]
# It appears these results are not too insightful given there are many non-alphabetical phrases and some stopwords.
# <br>
# Perhaps we should try this again after cleaning up our data by filtering out non-alphabetic phrases and stopwords...
# <br>
# <br>
# <br>
# Metric Set 5 (ATTEMPT 2):
# <br>
# 20 Most Common Adjectives and Adverbs by Frequency from Cleaned Data

# %%
#20 Most Common Adjectives
import re

#Remove non-alphabetic words
Monty_adjs = [word for word in Monty_adjs if re.compile('^[a-z]+$').match(word)]
Monty_advs = [word for word in Monty_advs if re.compile('^[a-z]+$').match(word)]
Knicks_adjs = [word for word in Knicks_adjs if re.compile('^[a-z]+$').match(word)]
Knicks_advs = [word for word in Knicks_advs if re.compile('^[a-z]+$').match(word)]
adjs = [word for word in adjs if re.compile('^[a-z]+$').match(word)]
advs = [word for word in advs if re.compile('^[a-z]+$').match(word)]

#Remove Stopwords
Monty_adjs = [word for word in Monty_adjs if not word in nltk.corpus.stopwords.words('english')]
Monty_advs = [word for word in Monty_advs if not word in nltk.corpus.stopwords.words('english')]
Knicks_adjs = [word for word in Knicks_adjs if not word in nltk.corpus.stopwords.words('english')]
Knicks_advs = [word for word in Knicks_advs if not word in nltk.corpus.stopwords.words('english')]
adjs = [word for word in adjs if not word in nltk.corpus.stopwords.words('english')]
advs = [word for word in advs if not word in nltk.corpus.stopwords.words('english')]

#Monty Python Adjectives
print('TOP 20 MONTY PYTHON ADJECTIVES')
for row in nltk.FreqDist(Monty_adjs).most_common()[:20]: print(row[0], row[1])
# Out:
# TOP 20 MONTY PYTHON ADJECTIVES
# mumble 30
# dead 22
# good 10
# sure 8
# old 7
# nice 7
# last 7
# squeak 7
# much 7
# dramatic 7
# second 6
# sacred 6
# um 6
# bad 6
# quiet 5
# dona 5
# silly 5
# afraid 5
# great 5
# simple 4

# %%
#Monty Python Adverbs
print('TOP 20 MONTY PYTHON ADVERBS')
for row in nltk.FreqDist(Monty_advs).most_common()[:20]: print(row[0], row[1])
# Out:
# TOP 20 MONTY PYTHON ADVERBS
# away 35
# back 9
# quite 7
# right 6
# well 6
# really 6
# else 5
# easily 5
# much 4
# enough 4
# better 4
# already 4
# yet 3
# anyway 3
# soon 3
# ever 3
# always 3
# apart 3
# bravely 3
# never 3

# %%
#Knicks History Adjectives
print('TOP 20 KNICKS HISTORY ADJECTIVES')
for row in nltk.FreqDist(Knicks_adjs).most_common()[:20]: print(row[0], row[1])
# Out:
# TOP 20 KNICKS HISTORY ADJECTIVES
# first 70
# second 22
# former 16
# next 12
# straight 7
# worst 7
# many 6
# new 6
# final 6
# general 5
# successful 5
# interim 5
# following 5
# consecutive 5
# regular 5
# professional 4
# last 4
# dismal 4
# good 4
# eventual 4

# %%
#Knicks History Adverbs
print('TOP 20 KNICKS HISTORY ADVERBS')
for row in nltk.FreqDist(Knicks_advs).most_common()[:20]: print(row[0], row[1])
# Out:
# TOP 20 KNICKS HISTORY ADVERBS
# also 18
# however 13
# later 9
# forward 9
# prior 6
# well 5
# still 5
# much 4
# together 3
# enough 3
# thus 3
# subsequently 3
# back 3
# properly 2
# originally 2
# twice 2
# immediately 2
# better 2
# respectively 2
# finally 2

# %%
#All Adjectives
print('TOP 20 ADJECTIVES IN COMBINED DOCUMENTS')
for row in nltk.FreqDist(adjs).most_common()[:20]: print(row[0], row[1])
# Out:
# TOP 20 ADJECTIVES IN COMBINED DOCUMENTS
# first 72
# mumble 30
# second 28
# dead 22
# former 16
# next 14
# good 14
# last 11
# many 10
# new 9
# sure 8
# much 8
# dramatic 8
# worst 8
# old 7
# nice 7
# squeak 7
# straight 7
# better 6
# sacred 6

# %%
#All Adverbs
print('TOP 20 ADVERBS IN COMBINED DOCUMENTS')
for row in nltk.FreqDist(advs).most_common()[:20]: print(row[0], row[1])
# Out:
# TOP 20 ADVERBS IN COMBINED DOCUMENTS
# away 36
# also 20
# however 13
# back 12
# well 11
# later 10
# forward 10
# much 8
# enough 7
# quite 7
# right 6
# better 6
# really 6
# easily 6
# still 6
# prior 6
# together 5
# ever 5
# else 5
# yet 4

# %% [markdown]
# Now, that is much more insightful! (at least for the Monty Python and Knicks History documents separately)
# <br>
# While the combined adverbs and adjectives are not particularly useful in this analysis, combining many different texts and doing this same type of analysis may begin to show the most common adjectives and adverbs that writers tend to use in general.

# %% [markdown]
# CONCLUSION:
# <br>
# <br>
# As stated earlier, countless metrics could be calcualted in this analysis, and I do believe that the ones calculated in this analysis were a good choice that told a lot about the texts. That being said, I was reminded in the very last step of the analysis while showing adjective and adverb frequencies that cleaning data was probably something that I should have done in the very first step, or at least in a separate analysis. The motivation behind not cleaning the data at first was to get descriptive statistics that were the most indicative of the actual documents, but I think since NLTK's word tokenization includes those stopwords and non-alphabetic phrases, that the cleaned data would have likely done a better job of that afterall. I also should have calculated the aggregated measures from Metric Sets 1-4 during those steps rather than at the end. This would have allowed for an accurate measure for the "Average ..." metrics and would have elimiated the need to include NaN's in the final metrics data frame. Both of these are things that I would do differently next time doing this analysis, but overall I think it went well.
# <br>
# <br>
# If I were to do a sentiment analysis on this, it would involve assigning single words, bigrams, trigrams, and full sentences a seniment score, then adding up all the sentiment scores to get four different sentiment scores for each of those analyses. One interesting idea, although it doesn't involve both documents used here, would be to do a sentiment analysis on all NBA teams' "History of ..." Wikipedia pages and compare it to the Knicks History sentiment. From there, those teams could be ranked by those sentiment scores and a correlation analysis could be done between those rankings and team success such as win percentage and number of championships won.

# %% [markdown]
# END OF HOMEWORK 2
